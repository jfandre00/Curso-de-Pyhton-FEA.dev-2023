# %% [markdown]
# # Aula de Pandas 2
#
# Na última aula tivemos uma introdução de pandas e aprendemos a realizar algumas operações essenciais de limpeza, filtragem e manipulação de dados. Além disso, também trabalhamos com algumas técnicas de visualização de dados usando a lib.
#
# Nesta aula, aprenderemos:
#
# - Como acessar nossas bases de dados utilizando os métodos Loc e iLoc;
# - Aprender sobre funções agregadoras e suas funcionalidades;
# - Aprender métodos úteis como groupby e pivot table;
# - Explorar alguns outros métodos como merge, diff, pct_change e shift.

# %% [markdown]
# # Importando pandas as pd

# %%
# import pandas as pd
import pandas as pd

# %%
# Importando as informações por pandas

# chamando o dataset
maiores_empresas = pd.read_csv("Largest_Companies.csv")

#testando o dataset
maiores_empresas.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and Cloud Computing
# 2     3         Exxon Mobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
maiores_empresas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    float64
#  5   Employees               100 non-null    int32
#  6   Headquarters            100 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(4)
# memory usage: 5.2+ KB

# %% [markdown]
# # 9.1.1 Loc e iLoc
#
# ## .loc
#
# A função loc será utilizada para localizar e acessar dados em seu dataframe a partir do nome de uma linha e/ou coluna e retornará os valores correspondentes às linhas e colunas nomeadas.
#
# Ex:
# df.loc[“nome da linha”, “nome da coluna”]

# %% [markdown]
# ## Selecionando apenas linhas com .loc

# %%
display(maiores_empresas)
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and Cloud Computing
# 2      3               Exxon Mobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions)  Revenue growth  Employees             Headquarters
# 0                 611,289             6.7    2100000    Bentonville, Arkansas
# 1                 513,983             9.4    1540000      Seattle, Washington
# 2                 413,680            44.8      62000            Spring, Texas
# 3                 394,328             7.8     164000    Cupertino, California
# 4                 324,162            12.7     400000    Minnetonka, Minnesota
# ..                    ...             ...        ...                      ...
# 95                 46,298            10.6      71100     Richfield, Minnesota
# 96                 46,159             0.5      34300  New York City, New York
# 97                 44,955            82.5      92795        Chicago, Illinois
# 98                 44,915            14.5     130000   Waltham, Massachusetts
# 99                 44,200            31.7      51000    San Diego, California
#
# [100 rows x 7 columns]

# %%
# Selecionando apenas linhas

# podemos chamar uma linha pelo seu índice

maiores_empresas.loc[0]
# Out:
# Rank                                          1
# Name                                    Walmart
# Industry                                 Retail
# Revenue (USD millions)                  611,289
# Revenue growth                              6.7
# Employees                               2100000
# Headquarters              Bentonville, Arkansas
# Name: 0, dtype: object

# %%
# podemos chamar um array de índices

maiores_empresas.loc[[0, 1, 3]]
# Out:
#    Rank     Name                    Industry Revenue (USD millions)  \
# 0     1  Walmart                      Retail                611,289
# 1     2   Amazon  Retail and Cloud Computing                513,983
# 3     4    Apple        Electronics industry                394,328
#
#    Revenue growth  Employees           Headquarters
# 0             6.7    2100000  Bentonville, Arkansas
# 1             9.4    1540000    Seattle, Washington
# 3             7.8     164000  Cupertino, California

# %%
# podemos chamar um intervalo de índices

#Exemplo: quais são as 5 maiores empresas
maiores_empresas.loc[0:4]
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and Cloud Computing
# 2     3         Exxon Mobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions)  Revenue growth  Employees           Headquarters
# 0                611,289             6.7    2100000  Bentonville, Arkansas
# 1                513,983             9.4    1540000    Seattle, Washington
# 2                413,680            44.8      62000          Spring, Texas
# 3                394,328             7.8     164000  Cupertino, California
# 4                324,162            12.7     400000  Minnetonka, Minnesota

# %% [markdown]
# ## .set_index
#
# Utilizando set_index para definir um índice a partir de uma coluna

# %%
# podemos achar a linha por seu valor contido

# primeiro devemos definir uma coluna como index por meio de set_index

maiores_empresas_index = maiores_empresas.set_index("Name")

#visualizando como ficou

maiores_empresas_index.head()
# Out:
#                     Rank                    Industry Revenue (USD millions)  \
# Name
# Walmart                1                      Retail                611,289
# Amazon                 2  Retail and Cloud Computing                513,983
# Exxon Mobil            3          Petroleum industry                413,680
# Apple                  4        Electronics industry                394,328
# UnitedHealth Group     5                  Healthcare                324,162
#
#                     Revenue growth  Employees           Headquarters
# Name
# Walmart                        6.7    2100000  Bentonville, Arkansas
# Amazon                         9.4    1540000    Seattle, Washington
# Exxon Mobil                   44.8      62000          Spring, Texas
# Apple                          7.8     164000  Cupertino, California
# UnitedHealth Group            12.7     400000  Minnetonka, Minnesota

# %%
#a partir disso, podemos buscar um valor contido dentro desta coluna

maiores_empresas_index.loc["Amazon"]
# Out:
# Rank                                               2
# Industry                  Retail and Cloud Computing
# Revenue (USD millions)                       513,983
# Revenue growth                                   9.4
# Employees                                    1540000
# Headquarters                     Seattle, Washington
# Name: Amazon, dtype: object

# %% [markdown]
# ## Selecionando apenas colunas com .loc

# %%
maiores_empresas.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and Cloud Computing
# 2     3         Exxon Mobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions)  Revenue growth  Employees           Headquarters
# 0                611,289             6.7    2100000  Bentonville, Arkansas
# 1                513,983             9.4    1540000    Seattle, Washington
# 2                413,680            44.8      62000          Spring, Texas
# 3                394,328             7.8     164000  Cupertino, California
# 4                324,162            12.7     400000  Minnetonka, Minnesota

# %%
# Selecionando apenas colunas por nomes
# usando a base de dados sem "name" como index
maiores_empresas.loc[:, ["Rank", "Name", "Revenue (USD millions)"]]
# Out:
#     Rank                      Name Revenue (USD millions)
# 0      1                   Walmart                611,289
# 1      2                    Amazon                513,983
# 2      3               Exxon Mobil                413,680
# 3      4                     Apple                394,328
# 4      5        UnitedHealth Group                324,162
# ..   ...                       ...                    ...
# 95    96                  Best Buy                 46,298
# 96    97      Bristol-Myers Squibb                 46,159
# 97    98           United Airlines                 44,955
# 98    99  Thermo Fisher Scientific                 44,915
# 99   100                  Qualcomm                 44,200
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Se eu estivesse usado o DataFrame que apliquei set_index?
# Não conseguiria usar, já que o nome está definido como index, logo ele não pode ser chamado como uma coluna na função .loc

# %%
# KeyError: "['Name'] not in index"
maiores_empresas_index.loc[:, ["Rank", "Name", "Revenue (USD millions)"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [62], in <cell line: 2>()
#       1 # KeyError: "['Name'] not in index"
# ----> 2 maiores_empresas_index.loc[:, ["Rank", "Name", "Revenue (USD millions)"]]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Name'] not in index"

# %%
# Não precisa chamar "Name", porque ele já está definido como index pelo python
maiores_empresas_index.loc[:, ["Rank", "Revenue (USD millions)"]]
# Out:
#                           Rank Revenue (USD millions)
# Name
# Walmart                      1                611,289
# Amazon                       2                513,983
# Exxon Mobil                  3                413,680
# Apple                        4                394,328
# UnitedHealth Group           5                324,162
# ...                        ...                    ...
# Best Buy                    96                 46,298
# Bristol-Myers Squibb        97                 46,159
# United Airlines             98                 44,955
# Thermo Fisher Scientific    99                 44,915
# Qualcomm                   100                 44,200
#
# [100 rows x 2 columns]

# %%
maiores_empresas_index.head()
# Out:
#                     Rank                    Industry Revenue (USD millions)  \
# Name
# Walmart                1                      Retail                611,289
# Amazon                 2  Retail and Cloud Computing                513,983
# Exxon Mobil            3          Petroleum industry                413,680
# Apple                  4        Electronics industry                394,328
# UnitedHealth Group     5                  Healthcare                324,162
#
#                     Revenue growth  Employees           Headquarters
# Name
# Walmart                        6.7    2100000  Bentonville, Arkansas
# Amazon                         9.4    1540000    Seattle, Washington
# Exxon Mobil                   44.8      62000          Spring, Texas
# Apple                          7.8     164000  Cupertino, California
# UnitedHealth Group            12.7     400000  Minnetonka, Minnesota

# %%
## Selecionando um conjunto de linhas e colunas

# Não se esqueça: precisamos primeiro definir alguma coluna como index -> note que defini o nome das empresas como index

# Não é necessário chamar "Name" como coluna na função .loc, já que ele já foi definido como index
maiores_empresas_index.loc[["Walmart", "Amazon", "Apple"], ["Rank", "Industry", "Revenue (USD millions)"]]
# Out:
#          Rank                    Industry Revenue (USD millions)
# Name
# Walmart     1                      Retail                611,289
# Amazon      2  Retail and Cloud Computing                513,983
# Apple       4        Electronics industry                394,328

# %% [markdown]
# ## Também podemos criar algumas condições a partir de .loc

# %%
# Como selecionar algumas colunas do dataframe a partir de algumas condições?

maiores_empresas.loc[(maiores_empresas["Industry"]) == "Retail"]
# Out:
#     Rank                Name Industry Revenue (USD millions)  Revenue growth  \
# 0      1             Walmart   Retail                611,289             6.7
# 11    12              Costco   Retail                226,954            15.8
# 19    20      The Home Depot   Retail                157,403             4.1
# 23    24              Kroger   Retail                148,258             7.5
# 32    33  Target Corporation   Retail                109,120             2.9
# 38    39              Lowe's   Retail                 97,059             0.8
# 52    53          Albertsons   Retail                 77,650             8.0
# 79    80              Publix   Retail                 54,942            13.5
# 88    89                 TJX   Retail                 49,936             2.9
# 95    96            Best Buy   Retail                 46,298            10.6
#
#     Employees                 Headquarters
# 0     2100000        Bentonville, Arkansas
# 11     304000         Issaquah, Washington
# 19     471600             Atlanta, Georgia
# 23     430000             Cincinnati, Ohio
# 32     440000       Minneapolis, Minnesota
# 38     244500  Mooresville, North Carolina
# 52     198650                 Boise, Idaho
# 79     242000            Lakeland, Florida
# 88     329000    Framingham, Massachusetts
# 95      71100         Richfield, Minnesota

# %%
maiores_empresas.loc[(maiores_empresas["Revenue growth"]) >= 50]
# Out:
#     Rank                    Name                          Industry  \
# 9     10     Chevron Corporation                Petroleum industry
# 16    17             Phillips 66                Petroleum industry
# 17    18           Valero Energy                Petroleum industry
# 48    49          ConocoPhillips                Petroleum industry
# 49    50                   Tesla             Automotive and Energy
# 60    61            StoneX Group                        Financials
# 65    66               TD Synnex                          Infotech
# 71    72     World Fuel Services  Petroleum industry and Logistics
# 86    87         Delta Air Lines                           Airline
# 90    91       American Airlines                           Airline
# 92    93  Performance Food Group                   Food Processing
# 93    94              PBF Energy                Petroleum industry
# 97    98         United Airlines                           Airline
#
#    Revenue (USD millions)  Revenue growth  Employees  \
# 9                 246,252            51.6      43846
# 16                175,702            53.0      13000
# 17                171,189            58.0       9743
# 48                 82,156            69.9       9500
# 49                 81,462            51.4     127855
# 60                 66,036            55.3        305
# 65                 62,344            97.2      28500
# 71                 59,043            88.4       5214
# 86                 50,582            69.2      95000
# 90                 48,971            63.9     129700
# 92                 47,194            61.6      34825
# 93                 46,830            71.8       3616
# 97                 44,955            82.5      92795
#
#                          Headquarters
# 9               San Ramon, California
# 16                     Houston, Texas
# 17                 San Antonio, Texas
# 48                     Houston, Texas
# 49                      Austin, Texas
# 60            New York City, New York
# 65                Clearwater, Florida
# 71                     Miami, Florida
# 86                   Atlanta, Georgia
# 90                  Fort Worth, Texas
# 92                 Richmond, Virginia
# 93  Parsippany–Troy Hills, New Jersey
# 97                  Chicago, Illinois

# %%
# Ou ainda, podemos modificar uma série de colunas

maiores_empresas.loc[[65,71], "Revenue growth"] = 15

maiores_empresas.loc[[65,71]]
# Out:
#     Rank                 Name                          Industry  \
# 65    66            TD Synnex                          Infotech
# 71    72  World Fuel Services  Petroleum industry and Logistics
#
#    Revenue (USD millions)  Revenue growth  Employees         Headquarters
# 65                 62,344            15.0      28500  Clearwater, Florida
# 71                 59,043            15.0       5214       Miami, Florida

# %% [markdown]
# ## # 9.1.2 Loc e iLoc
#
# ## .iloc
#
# Da mesma forma que a função loc a função iloc será utilizada para localizar e acessar dados em seu dataframe. Porém, iloc utiliza os índices numéricos ao invés dos nomes das linhas e colunas.
#
# Ex:
# df.loc[“número da linha”, “número da coluna”]

# %%
# Selecionando apenas a primeira linha

maiores_empresas.iloc[0]
# Out:
# Rank                                          1
# Name                                    Walmart
# Industry                                 Retail
# Revenue (USD millions)                  611,289
# Revenue growth                              6.7
# Employees                               2100000
# Headquarters              Bentonville, Arkansas
# Name: 0, dtype: object

# %%
# Selecionando apenas a primeira coluna

maiores_empresas.iloc[0, 1]
# Out:
# 'Walmart'

# %%
# Selecionando algumas linhas e colunas

maiores_empresas.iloc[[0, 1, 2,3], [0, 1,2,3]]
# Out:
#    Rank         Name                    Industry Revenue (USD millions)
# 0     1      Walmart                      Retail                611,289
# 1     2       Amazon  Retail and Cloud Computing                513,983
# 2     3  Exxon Mobil          Petroleum industry                413,680
# 3     4        Apple        Electronics industry                394,328

# %%
# Limitado, não é possível chamar pelos nomes, mesmo que o index seja definido como "Name"

maiores_empresas_index.iloc["Amazon"]

# Cannot index by location index with a non-integer key
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 3>()
#       1 # Limitado, não é possível chamar pelos nomes, mesmo que o index seja definido como "Name"
# ----> 3 maiores_empresas_index.iloc["Amazon"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1517, in _iLocIndexer._getitem_axis(self, key, axis)
#    1515 key = item_from_zerodim(key)
#    1516 if not is_integer(key):
# -> 1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
# Em .iloc não é possível selecionar um intervalo, para isso, precisamos utilizar range(n), como veremos a seguir

maiores_empresas.iloc[[0:2],[0:4]]

# %%
# Selecionando algumas linhas e colunas

maiores_empresas.iloc[range(2),range(4)]
# Out:
#    Rank     Name                    Industry Revenue (USD millions)
# 0     1  Walmart                      Retail                611,289
# 1     2   Amazon  Retail and Cloud Computing                513,983

# %% [markdown]
# ## Ao adicionar .name ao final de uma função iloc é possível obter o nome de uma linha ou coluna a partir de seu índice.

# %%
# df.iloc[linha, coluna]
maiores_empresas.iloc[:, 2].name
# Out:
# 'Industry'

# %% [markdown]
# ## É também possível usar o método .unique() após uma função loc ou iloc para retornar apenas valores únicos caso existam duplicatas.

# %%
# Utilizando a função .unique()

maiores_empresas.iloc[:, 1].unique()
# Out:
# array(['Walmart', 'Amazon', 'Exxon Mobil', 'Apple', 'UnitedHealth Group',
#        'CVS Health', 'Berkshire Hathaway', 'Alphabet',
#        'McKesson Corporation', 'Chevron Corporation', 'AmerisourceBergen',
#        'Costco', 'Microsoft', 'Cardinal Health', 'Cigna',
#        'Marathon Petroleum', 'Phillips 66', 'Valero Energy',
#        'Ford Motor Company', 'The Home Depot', 'General Motors',
#        'Elevance Health', 'JPMorgan Chase', 'Kroger', 'Centene',
#        'Verizon Communications', 'Walgreens Boots Alliance', 'Fannie Mae',
#        'Comcast', 'AT&T', 'Meta Platforms', 'Bank of America',
#        'Target Corporation', 'Dell Technologies',
#        'Archer Daniels Midland', 'Citigroup', 'United Parcel Service',
#        'Pfizer', "Lowe's", 'Johnson & Johnson', 'FedEx', 'Humana',
#        'Energy Transfer Partners', 'State Farm', 'Freddie Mac', 'PepsiCo',
#        'Wells Fargo', 'The Walt Disney Company', 'ConocoPhillips',
#        'Tesla', 'Procter & Gamble', 'United States Postal Service',
#        'Albertsons', 'General Electric', 'MetLife', 'Goldman Sachs',
#        'Sysco', 'Bunge Limited', 'RTX Corporation', 'Boeing',
#        'StoneX Group', 'Lockheed Martin', 'Morgan Stanley', 'Intel', 'HP',
#        'TD Synnex', 'IBM', 'HCA Healthcare', 'Prudential Financial',
#        'Caterpillar', 'Merck & Co.', 'World Fuel Services',
#        'New York Life Insurance Company', 'Enterprise Products', 'AbbVie',
#        'Plains All American Pipeline', 'Dow Chemical Company', 'AIG',
#        'American Express', 'Publix', 'Charter Communications',
#        'Tyson Foods', 'John Deere', 'Cisco',
#        'Nationwide Mutual Insurance Company', 'Allstate',
#        'Delta Air Lines', 'Liberty Mutual', 'TJX',
#        'Progressive Corporation', 'American Airlines', 'CHS',
#        'Performance Food Group', 'PBF Energy', 'Nike', 'Best Buy',
#        'Bristol-Myers Squibb', 'United Airlines',
#        'Thermo Fisher Scientific', 'Qualcomm'], dtype=object)

# %% [markdown]
# # 9.2 O que é uma função agregadora?
#
# No pandas, uma função agregadora refere-se a uma função que realiza um cálculo em um conjunto de valores de um DataDrame ou Série e retorna um único valor como resultado. Elas são particularmente úteis ao lidar com um conjunto de dados grande ou na extração eficiente de informações.
#
# Essas funções são frequentemente usadas em conjunto com a operação .groupby()  para agrupar dados com base em determinados critérios e, em seguida, calcular estatísticas para cada agrupamento.

# %% [markdown]
# ## Exemplos de funções agregadoras:
# - sum(): Calcula o somatório dos valores num agrupamento
# - median():Calcula a mediana dos valores num agrupamento
# - min(): Encontra o valor mínimo num agrupamento
# - max(): Encontra o valor máximo num agrupamento
# - count(): Conta o número de valores não nulos num agrupamento

# %% [markdown]
# ## 9.3 Métodos Úteis
#
# ## 9.3.1 Groupby
#
# O método .groupby() organiza o data frame em grupos baseado no resultado de uma ou mais colunas e permite realizar funções agregadoras a um conjunto de dados.

# %%
vendas_mercado = pd.read_csv("supermarket_sales.csv")

vendas_mercado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
display(vendas_mercado)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
# O método .groupby() organiza o data frame em grupos baseado no resultado de uma ou mais colunas 

vendas_mercado.groupby("Payment")["Quantity"].count()

# Agrupamos por método de pagamento e queremos saber a quantidade vendida por tipo de método
# Out:
# Payment
# Cash           344
# Credit card    311
# Ewallet        345
# Name: Quantity, dtype: int64

# %%
# Segue um exemplo
vendas_mercado.groupby("Product line")["Quantity"].count()

# Agrupamos por produtos e queremos saber a quantidade que as pessoas compram por produto
# Out:
# Product line
# Electronic accessories    170
# Fashion accessories       178
# Food and beverages        174
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# Name: Quantity, dtype: int64

# %%
# O método .groupby() pode agrupar dados com base em mais de uma coluna.

# Segue um exemplo
vendas_mercado.groupby(["Product line","Gender"])["Quantity"].count()

# Agrupamos por linha de produto e queremos saber a quantidade gasta por cada gênero
# Out:
# Product line            Gender
# Electronic accessories  Female    84
#                         Male      86
# Fashion accessories     Female    96
#                         Male      82
# Food and beverages      Female    90
#                         Male      84
# Health and beauty       Female    64
#                         Male      88
# Home and lifestyle      Female    79
#                         Male      81
# Sports and travel       Female    88
#                         Male      78
# Name: Quantity, dtype: int64

# %%
# Da mesma forma, podemos querer saber o faturamento total por branch (cada uma das três cidades)
vendas_mercado.groupby("City")["Total"].sum()
# Out:
# City
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: Total, dtype: float64

# %% [markdown]
# # Recapitulando

# %% [markdown]
# - sum(): Calcula o somatório dos valores num agrupamento
# - median():Calcula a mediana dos valores num agrupamento
# - min(): Encontra o valor mínimo num agrupamento
# - max(): Encontra o valor máximo num agrupamento
# - count(): Conta o número de valores não nulos num agrupamento

# %% [markdown]
# ## 9.3.2 Pivot Table
#
# Especialmente úteis para lidar com grandes bases de dados, a pivot table é uma ferramente de manipulação de dados que nos permite agrupar e reconfigurar dados em formato de tabela. O método nos permite agregar, analisar, visualizar rapidamente dados de um DataFrame.
#
# Podemos construir uma pivot table a partir de:
#  - De um index (Index)
#  - Colunas de interesse (Columns)
#  - Valores que queremos agregar (values)
#  - Função agregadora (aggfunc)

# %% [markdown]
# *A partir de um pivot table é possível reconfigurar os dados de um DataFrame para descobrir a quantidade total de cada item vendido por cada vendedor de uma loja.

# %%
# Exemplo

vendas_mercado.pivot_table(index="City", columns=["Product line", "Gender"], values="Total", aggfunc="sum")

# Queremos saber a soma do faturamento por genêros dentro de cada linha de produto, separado por cidade.
# Out:
# Product line Electronic accessories           Fashion accessories              \
# Gender                       Female      Male              Female        Male
# City
# Mandalay                  8166.5115  8884.932           9081.4920   7331.8245
# Naypyitaw                 8969.2155  9999.759          11519.6865  10040.3835
# Yangon                    9966.2955  8350.818           9836.2215   6496.2870
#
# Product line Food and beverages             Health and beauty              \
# Gender                   Female        Male            Female        Male
# City
# Mandalay             10509.9960   4704.8925         6400.3485  13580.3115
# Naypyitaw            15661.1595   8105.6955         6445.7400  10169.5860
# Yangon                6999.7620  10163.3385         5714.8980   6882.8550
#
# Product line Home and lifestyle            Sports and travel
# Gender                   Female       Male            Female        Male
# City
# Mandalay              9557.1315  7992.0330         9212.8155  10775.3835
# Naypyitaw             7842.9330  6052.6200        11246.7285   4515.1995
# Yangon               12636.8130  9780.3825         8115.1770  11257.5225

# %% [markdown]
# ## 9.3.3 Merge
#
# pd.merge(df1, df2, on = "nome_da_coluna")
#
# É utilizada para unir dois ou mais DataFrames com base em colunas ou índices em comum, ou seja, unir múltiplas fontes em um único DataFrame, permitindo análise e exploração abragente dos dados combinados.

# %% [markdown]
# *O método possibilita unir dois DataFrames que especificam o salário e a idade de uma pessoa em um único DataFrame com os dados de ambas as tabelas.

# %%
# Temos os salários e informações dos funcionários em uma planilha

salario_funcionarios = pd.read_excel("salario.xlsx")

#pd.read_excel pode ser usado para arquivos xlsx, ou seja arquivos excel salvos como tipo "Planilha do Microsoft Excel"

#testando o dataset
display(salario_funcionarios)
# Out:
#          Nome  Salário          Branch       Setor
# 0     Fabiano     6500  Rio de Janeiro  Financeiro
# 1       Maria     3682       São Paulo   Comercial
# 2       Julia     2088       São Paulo   Comercial
# 3      Arthur     5425  Rio de Janeiro  Financeiro
# 4      Carlos     2232  Rio de Janeiro  Financeiro
# 5      Marcos     4433       São Paulo   Comercial
# 6         Ana     6058  Rio de Janeiro  Financeiro
# 7       Luiza     2446  Rio de Janeiro   Comercial
# 8       Sofia     1964  Rio de Janeiro   Comercial
# 9      Sergio     2486       São Paulo   Comercial
# 10     Felipe     7010       São Paulo   Comercial
# 11      Lucas     7190  Rio de Janeiro  Financeiro
# 12       Luis     5024       São Paulo  Financeiro
# 13    Cinthia     6613       São Paulo   Comercial
# 14      Carla     5820  Rio de Janeiro  Financeiro
# 15       Tais     2424  Rio de Janeiro   Comercial
# 16     Mateus     6874       São Paulo  Financeiro
# 17     Camila     6099  Rio de Janeiro   Comercial
# 18       Igor     6719       São Paulo   Comercial
# 19    Natalia     4310       São Paulo  Financeiro
# 20    Fabiana     3360  Rio de Janeiro  Financeiro
# 7       Luiza     2446  Rio de Janeiro   Comercial     25   Feminino
# 8       Sofia     1964  Rio de Janeiro   Comercial     25   Feminino
# 9      Sergio     2486       São Paulo   Comercial     26  Masculino
# 10     Felipe     7010       São Paulo   Comercial     31  Masculino
# 11      Lucas     7190  Rio de Janeiro  Financeiro     30  Masculino
# 12       Luis     5024       São Paulo  Financeiro     27  Masculino
# 13    Cinthia     6613       São Paulo   Comercial     28   Feminino
# 14      Carla     5820  Rio de Janeiro  Financeiro     27   Feminino
# 15       Tais     2424  Rio de Janeiro   Comercial     30   Feminino
# 16     Mateus     6874       São Paulo  Financeiro     30  Masculino
# 17     Camila     6099  Rio de Janeiro   Comercial     28   Feminino
# 18       Igor     6719       São Paulo   Comercial     27  Masculino
# 19    Natalia     4310       São Paulo  Financeiro     27   Feminino
# 20    Fabiana     3360  Rio de Janeiro  Financeiro     24   Feminino
# 21    Beatriz     3546       São Paulo   Comercial     23   Feminino
# 22     Bianca     7487       São Paulo  Financeiro     24   Feminino
# 23       João     6629  Rio de Janeiro   Comercial     22  Masculino
# 24      Paulo     5796  Rio de Janeiro   Comercial     23  Masculino
# 25      Pedro     5393       São Paulo   Comercial     30  Masculino
# 26    Leticia     4390  Rio de Janeiro  Financeiro     32   Feminino
# 27   Henrique     5715       São Paulo   Comercial     25  Masculino
# 28  Guilherme     5021  Rio de Janeiro   Comercial     29  Masculino
# 29      Karen     7304  Rio de Janeiro  Financeiro     30   Feminino

# %% [markdown]
# ## 9.3.4 Diff
#
# Sendo muito útil para analisar a taxa de varição ou tendência de uma base de dados, a função retornará todas as variações entre uma linha e sua anterior para cada coluna do DataFrame. No caso de uma Series a função retornará apenas uma coluna.

# %%
# PIB do Brasil

pib = pd.read_excel("pib_brasil.xlsx")
display(pib)
# Out:
#    Período      PIB
# 0   1T2019  1756054
# 1   2T2019  1825143
# 2   3T2019  1880548
# 3   4T2019  1927386
# 4   1T2020  1873398
# 5   2T2020  1757517
# 6   3T2020  1929703
# 7   4T2020  2048979
# 8   1T2021  2152622
# 9   2T2021  2182049
# 10  3T2021  2254492
# 11  4T2021  2309564
# 12  1T2022  2315709
# 13  2T2022  2471837
# 14  3T2022  2543645
# 15  4T2022  2584126
# 16  1T2023  2556531
# 17  2T2023  2651156

# %%
# Exemplo

pib["PIB"].diff()
# Out:
# 0          NaN
# 1      69089.0
# 2      55405.0
# 3      46838.0
# 4     -53988.0
# 5    -115881.0
# 6     172186.0
# 7     119276.0
# 8     103643.0
# 9      29427.0
# 10     72443.0
# 11     55072.0
# 12      6145.0
# 13    156128.0
# 14     71808.0
# 15     40481.0
# 16    -27595.0
# 17     94625.0
# Name: PIB, dtype: float64

# %% [markdown]
# ## periods = n
#
# Para periods=1 (default) a função calcula a diferença entre a linha atual e a última linha, para periods=2 a função calcula a diferença entre a linha atual e a antepenúltima linha.

# %%
# Exemplo

pib["PIB"].diff(periods = 4)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4     117344.0
# 5     -67626.0
# 6      49155.0
# 7     121593.0
# 8     279224.0
# 9     424532.0
# 10    324789.0
# 11    260585.0
# 12    163087.0
# 13    289788.0
# 14    289153.0
# 15    274562.0
# 16    240822.0
# 17    179319.0
# Name: PIB, dtype: float64

# %% [markdown]
# ## 9.3.5 Pct_change
#
# O método pct_change opera de maneira similar ao diff(), porém, ao invés de retornar valores absolutos, a função retorna a variação percentual entre valores consecutivos.
#
# O método no auxilia a analisar o crescimento ou declínio relativo dos pontos de dados, especialmente em situações em que é importante compreender a taxa de mudança, tais como análises financeiras.

# %%
# Exemplo 

# Multiplicamos por 100 para termos os valores percentuais
pib["PIB"].pct_change()*100
# Out:
# 0          NaN
# 1     3.934332
# 2     3.035653
# 3     2.490657
# 4    -2.801100
# 5    -6.185605
# 6     9.797117
# 7     6.181055
# 8     5.058275
# 9     1.367031
# 10    3.319953
# 11    2.442768
# 12    0.266068
# 13    6.742125
# 14    2.905046
# 15    1.591456
# 16   -1.067866
# 17    3.701305
# Name: PIB, dtype: float64

# %%
# Também é possível utilizar periods = n

pib["PIB"].pct_change(periods = 4)*100
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4      6.682255
# 5     -3.705244
# 6      2.613866
# 7      6.308700
# 8     14.904681
# 9     24.155214
# 10    16.831036
# 11    12.717797
# 12     7.576202
# 13    13.280545
# 14    12.825639
# 15    11.888045
# 16    10.399493
# 17     7.254483
# Name: PIB, dtype: float64

# %% [markdown]
# ## 9.3.6 Shift
#
# Útil para análise de séries em função do tempo, cálculo de diferenças entre valores deslocados e execução de vários tipos de transformações de dados, a função shift() é usada para deslocar os valores de uma série ou DataFrame ao longo de um eixo específico, ou seja, movê-los para cima ou para baixo nas posições do índice.

# %%
# Exemplo: todos os valores do DataFrame são deslocados duas linhas abaixo

pib_shift = pib.shift(periods=2)

display(pib_shift)
# Out:
#    Período        PIB
# 0      NaN        NaN
# 1      NaN        NaN
# 2   1T2019  1756054.0
# 3   2T2019  1825143.0
# 4   3T2019  1880548.0
# 5   4T2019  1927386.0
# 6   1T2020  1873398.0
# 7   2T2020  1757517.0
# 8   3T2020  1929703.0
# 9   4T2020  2048979.0
# 10  1T2021  2152622.0
# 11  2T2021  2182049.0
# 12  3T2021  2254492.0
# 13  4T2021  2309564.0
# 14  1T2022  2315709.0
# 15  2T2022  2471837.0
# 16  3T2022  2543645.0
# 17  4T2022  2584126.0

# %% [markdown]
# ## fillna()
#
# Note que quando todos os valores são deslocados para baixo os valores do topo acabam por ficarem vazios. Desta forma, é possível definir um parâmetro fillna(value = n) que preenche valores vazios criados pelo deslocamento.

# %%
# pode fazer a busca dos valores vazios, para saber quantos precisam ser preenchidos

#isnull().sum()

print(pib_shift.isnull().sum())
# Out:
# Período    2
# PIB        2
# dtype: int64

# %%
# para alterar os valores para 0

pib_shift2 = pib_shift.fillna(value = 0)

pib_shift2.head()
# Out:
#   Período        PIB
# 0       0        0.0
# 1       0        0.0
# 2  1T2019  1756054.0
# 3  2T2019  1825143.0
# 4  3T2019  1880548.0

# %%
# Da mesma forma, pode se alterar para qualquer outro valor que desejar

pib_shift25 = pib_shift.fillna(value = 25)

pib_shift25.head()
# Out:
#   Período        PIB
# 0      25       25.0
# 1      25       25.0
# 2  1T2019  1756054.0
# 3  2T2019  1825143.0
# 4  3T2019  1880548.0
