# %%
#https://www.kaggle.com/datasets/elmartini/gender-development-index-2019
import pandas as pd

df = pd.read_csv('GDI.csv')
df.describe()
# Out:
#          HDI Rank
# count  189.000000
# mean    94.783069
# std     54.754486
# min      1.000000
# 25%     48.000000
# 50%     95.000000
# 75%    142.000000
# max    189.000000

# %%
df.head(20)
#Vamos precisar deletar a linha 0, pois só mostra informações sobre o ano.
# Out:
#     HDI Rank                 Country GDI_Value GDI_Group HDI_Female HDI_Male  \
# 0        NaN                     NaN      2019      2019       2019     2019
# 1        1.0                  Norway     0.990         1      0.949    0.959
# 2        2.0                 Ireland     0.981         1      0.943    0.961
# 3        2.0             Switzerland     0.968         2      0.934    0.965
# 4        4.0  Hong Kong, China (SAR)     0.972         2      0.933    0.959
# 5        4.0                 Iceland     0.969         2      0.933    0.963
# 6        6.0                 Germany     0.972         2      0.933    0.960
# 7        7.0                  Sweden     0.983         1      0.936    0.953
# 8        8.0               Australia     0.976         1      0.932    0.955
# 9        8.0             Netherlands     0.966         2      0.926    0.960
# 10      10.0                 Denmark     0.983         1      0.931    0.948
# ...

# %%
df = df.drop(0)

# %%
df.head(20)
# Out:
#     HDI Rank                 Country GDI_Value GDI_Group HDI_Female HDI_Male  \
# 1        1.0                  Norway     0.990         1      0.949    0.959
# 2        2.0                 Ireland     0.981         1      0.943    0.961
# 3        2.0             Switzerland     0.968         2      0.934    0.965
# 4        4.0  Hong Kong, China (SAR)     0.972         2      0.933    0.959
# 5        4.0                 Iceland     0.969         2      0.933    0.963
# 6        6.0                 Germany     0.972         2      0.933    0.960
# 7        7.0                  Sweden     0.983         1      0.936    0.953
# 8        8.0               Australia     0.976         1      0.932    0.955
# 9        8.0             Netherlands     0.966         2      0.926    0.960
# 10      10.0                 Denmark     0.983         1      0.931    0.948
# 11      11.0                 Finland     0.990         1      0.932    0.942
# ...
