# %%
import pandas as pd

df = pd.read_csv('running_best_cities.csv')
df.head(50)
# Out:
#     Overall Rank (1=Best)              City State  Overall Score  \
# 0                       1     San Francisco    CA          57.96
# 1                       2          New York    NY          56.97
# 2                       3         San Diego    CA          55.53
# 3                       4          Portland    OR          55.23
# 4                       5           Oakland    CA          53.47
# 5                       6       Los Angeles    CA          49.34
# 6                       7           Seattle    WA          48.88
# 7                       8            Boston    MA          47.69
# 8                       9    Salt Lake City    UT          47.16
# 9                      10          San Jose    CA          47.07
# 10                     11          Glendale    CA          46.78
# 11                     12        Washington    DC          46.67
# 12                     13  Colorado Springs    CO          46.23
# ...

# %%
df.tail(20)
# Out:
#      Overall Rank (1=Best)              City State  Overall Score  \
# 180                    181           McAllen    TX          27.19
# 181                    182          Thornton    CO          27.10
# 182                    183    Pembroke Pines    FL          27.03
# 183                    184   North Las Vegas    NV          26.83
# 184                    185        Cape Coral    FL          26.80
# 185                    186           Detroit    MI          26.79
# 186                    187     Grand Prairie    TX          26.66
# 187                    188          Mesquite    TX          26.50
# 188                    189       Baton Rouge    LA          26.48
# 189                    190       Clarksville    TN          26.10
# 190                    191          Amarillo    TX          26.00
# 191                    192  West Valley City    UT          25.54
# 192                    193           Ontario    CA          25.30
# ...

# %%
resultado = list(df['State'] == 'NC')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)           City State  Overall Score  \
# 43                      44        Raleigh    NC          39.55
# 60                      61         Durham    NC          38.42
# 71                      72      Charlotte    NC          37.37
# 114                    115     Greensboro    NC          33.56
# 159                    160   Fayetteville    NC          30.10
# 163                    164  Winston-Salem    NC          29.83
#
#      Running Access Rank  Running Quality Rank  Foot Care Rank  \
# 43                    35                    70             137
# 60                    41                   116              72
# 71                    72                   123             132
# 114                   90                    86             131
# 159                  192                   137             118
# 163                  161                   166              73
#
#      Affordability Rank  Community Rank  Safety Rank  Climate Rank
# ...

# %%
resultado = list(df['State'] == 'VA')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)            City State  Overall Score  \
# 14                      15        Richmond    VA          45.62
# 31                      32  Virginia Beach    VA          42.05
# 54                      55      Alexandria    VA          39.00
# 120                    121    Newport News    VA          33.37
# 128                    129      Chesapeake    VA          32.91
# 139                    140         Norfolk    VA          32.37
# 160                    161         Hampton    VA          30.06
#
#      Running Access Rank  Running Quality Rank  Foot Care Rank  \
# 14                    17                    29              22
# 31                    62                    31             148
# 54                    59                    43              51
# 120                  172                    56             109
# 128                  125                   170             176
# 139                  129                   100             163
# ...

# %%
df.sort_values(by = 'Running Quality Rank').head(20)
# Out:
#     Overall Rank (1=Best)            City State  Overall Score  \
# 0                       1   San Francisco    CA          57.96
# 10                     11        Glendale    CA          46.78
# 27                     28        Pasadena    CA          42.56
# 26                     27         Anaheim    CA          42.76
# 4                       5         Oakland    CA          53.47
# 5                       6     Los Angeles    CA          49.34
# 19                     20         Salinas    CA          44.42
# 25                     26          Oxnard    CA          43.23
# 18                     19    Philadelphia    PA          44.60
# 22                     23         Phoenix    AZ          43.70
# 3                       4        Portland    OR          55.23
# 7                       8          Boston    MA          47.69
# 15                     16         Fremont    CA          45.48
# 9                      10        San Jose    CA          47.07
# ...

# %%
df.sort_values(by = 'Climate Rank').head(60)
# Out:
#      Overall Rank (1=Best)              City State  Overall Score  \
# 13                      14        Santa Rosa    CA          45.66
# 32                      33          Honolulu    HI          41.61
# 19                      20           Salinas    CA          44.42
# 45                      46       Chula Vista    CA          39.53
# 2                        3         San Diego    CA          55.53
# 23                      24         Escondido    CA          43.56
# 82                      83         Oceanside    CA          36.53
# 15                      16           Fremont    CA          45.48
# 67                      68           Hayward    CA          38.01
# 0                        1     San Francisco    CA          57.96
# 9                       10          San Jose    CA          47.07
# 59                      60         Sunnyvale    CA          38.62
# 4                        5           Oakland    CA          53.47
# ...

# %%
df.sort_values(by = 'Safety Rank').head(40)
# Out:
#      Overall Rank (1=Best)             City State  Overall Score  \
# 29                      30       Naperville    IL          42.28
# 157                    158   Port St. Lucie    FL          30.20
# 57                      58         McKinney    TX          38.81
# 48                      49    Santa Clarita    CA          39.43
# 107                    108           Frisco    TX          34.24
# 93                      94          Yonkers    NY          35.86
# 184                    185       Cape Coral    FL          26.80
# 131                    132           Aurora    IL          32.78
# 95                      96          Miramar    FL          35.69
# 21                      22           Irvine    CA          43.74
# 151                    152        Elk Grove    CA          31.00
# 117                    118       Carrollton    TX          33.50
# 144                    145           Joliet    IL          31.61
# ...

# %%
resultado = list(df['State'] == 'FL')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)             City State  Overall Score  \
# 36                      37            Miami    FL          41.10
# 89                      90   St. Petersburg    FL          36.22
# 92                      93            Tampa    FL          36.06
# 95                      96          Miramar    FL          35.69
# 102                    103          Orlando    FL          34.48
# 111                    112     Jacksonville    FL          33.96
# 113                    114      Tallahassee    FL          33.66
# 115                    116  Fort Lauderdale    FL          33.56
# 148                    149          Hialeah    FL          31.36
# 153                    154        Hollywood    FL          30.66
# 157                    158   Port St. Lucie    FL          30.20
# 182                    183   Pembroke Pines    FL          27.03
# 184                    185       Cape Coral    FL          26.80
#
# ...

# %%
estados = df.groupby('State')['City'].count()
display(estados)
# Out:
# State
# AK     1
# AL     4
# AR     1
# AZ     9
# CA    43
# CO     6
# CT     1
# DC     1
# FL    13
# GA     5
# HI     1
# IA     1
# ID     1
# IL     5
# IN     2
# KS     4
# KY     2
# LA     3
# MA     3
# MD     1
# MI     3
# MN     2
# MO     3
# MS     1
# NC     6
# NE     2
# NJ     3
# NM     1
# NV     4
# NY     5
# OH     6
# OK     2
# OR     3
# PA     2
# RI     1
# SC     1
# SD     1
# TN     6
# TX    25
# UT     2
# VA     7
# WA     5
# WI     2
# Name: City, dtype: int64

# %%
resultado = list(df['State'] == 'TX')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)            City State  Overall Score  \
# 30                      31     San Antonio    TX          42.14
# 38                      39          Austin    TX          40.80
# 46                      47         El Paso    TX          39.51
# 52                      53           Plano    TX          39.11
# 57                      58        McKinney    TX          38.81
# 62                      63         Houston    TX          38.20
# 75                      76          Dallas    TX          37.18
# 78                      79            Waco    TX          37.07
# 99                     100      Fort Worth    TX          35.14
# 107                    108          Frisco    TX          34.24
# 116                    117       Arlington    TX          33.53
# 117                    118      Carrollton    TX          33.50
# 135                    136          Irving    TX          32.53
# 147                    148          Laredo    TX          31.38
# ...

# %%
estados = df['State'].value_counts()
display(estados)
# Out:
# CA    43
# TX    25
# FL    13
# AZ     9
# VA     7
# OH     6
# TN     6
# NC     6
# CO     6
# WA     5
# NY     5
# GA     5
# IL     5
# KS     4
# AL     4
# NV     4
# MO     3
# LA     3
# MI     3
# OR     3
# NJ     3
# MA     3
# IN     2
# OK     2
# NE     2
# WI     2
# KY     2
# UT     2
# MN     2
# PA     2
# AR     1
# SD     1
# CT     1
# AK     1
# MD     1
# SC     1
# IA     1
# RI     1
# NM     1
# HI     1
# ID     1
# DC     1
# MS     1
# Name: State, dtype: int64

# %%
resultado = list(df['State'] == 'VA')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)            City State  Overall Score  \
# 14                      15        Richmond    VA          45.62
# 31                      32  Virginia Beach    VA          42.05
# 54                      55      Alexandria    VA          39.00
# 120                    121    Newport News    VA          33.37
# 128                    129      Chesapeake    VA          32.91
# 139                    140         Norfolk    VA          32.37
# 160                    161         Hampton    VA          30.06
#
#      Running Access Rank  Running Quality Rank  Foot Care Rank  \
# 14                    17                    29              22
# 31                    62                    31             148
# 54                    59                    43              51
# 120                  172                    56             109
# 128                  125                   170             176
# 139                  129                   100             163
# ...

# %%
resultado = list(df['State'] == 'OR')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)      City State  Overall Score  \
# 3                        4  Portland    OR          55.23
# 53                      54    Eugene    OR          39.04
# 125                    126     Salem    OR          33.07
#
#      Running Access Rank  Running Quality Rank  Foot Care Rank  \
# 3                      1                    11              43
# 53                    49                    57              80
# 125                  120                   164              95
#
#      Affordability Rank  Community Rank  Safety Rank  Climate Rank
# 3                   157              12          154            15
# 53                  122              72          105            46
# 125                 111              93          150            17

# %%
resultado = list(df['State'] == 'CA')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)              City State  Overall Score  \
# 0                        1     San Francisco    CA          57.96
# 2                        3         San Diego    CA          55.53
# 4                        5           Oakland    CA          53.47
# 5                        6       Los Angeles    CA          49.34
# 9                       10          San Jose    CA          47.07
# 10                      11          Glendale    CA          46.78
# 13                      14        Santa Rosa    CA          45.66
# 15                      16           Fremont    CA          45.48
# 19                      20           Salinas    CA          44.42
# 21                      22            Irvine    CA          43.74
# 23                      24         Escondido    CA          43.56
# 25                      26            Oxnard    CA          43.23
# 26                      27           Anaheim    CA          42.76
# ...

# %%
resultado = list(df['State'] == 'NJ')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)         City State  Overall Score  \
# 50                      51  Jersey City    NJ          39.25
# 145                    146       Newark    NJ          31.58
# 166                    167     Paterson    NJ          29.74
#
#      Running Access Rank  Running Quality Rank  Foot Care Rank  \
# 50                    96                    20             101
# 145                  117                    28             165
# 166                  152                   152             105
#
#      Affordability Rank  Community Rank  Safety Rank  Climate Rank
# 50                   37             106           40           125
# 145                 200             175          131           129
# 166                 190             185           46           125

# %%
resultado = list(df['State'] == 'WA')
display(df.loc[resultado])
# Out:
#      Overall Rank (1=Best)       City State  Overall Score  \
# 6                        7    Seattle    WA          48.88
# 56                      57   Bellevue    WA          38.92
# 70                      71    Spokane    WA          37.46
# 87                      88     Tacoma    WA          36.26
# 108                    109  Vancouver    WA          34.23
#
#      Running Access Rank  Running Quality Rank  Foot Care Rank  \
# 6                     21                    16              62
# 56                    45                   129              36
# 70                    40                   102              52
# 87                    89                   142              33
# 108                   87                   179              97
#
#      Affordability Rank  Community Rank  Safety Rank  Climate Rank
# 6                    58              11          133            18
# 56                   88             174           57            18
# ...

# %%
df.sort_values(by = 'Climate Rank').head(50)
# Out:
#      Overall Rank (1=Best)              City State  Overall Score  \
# 13                      14        Santa Rosa    CA          45.66
# 32                      33          Honolulu    HI          41.61
# 19                      20           Salinas    CA          44.42
# 45                      46       Chula Vista    CA          39.53
# 2                        3         San Diego    CA          55.53
# 23                      24         Escondido    CA          43.56
# 82                      83         Oceanside    CA          36.53
# 15                      16           Fremont    CA          45.48
# 67                      68           Hayward    CA          38.01
# 0                        1     San Francisco    CA          57.96
# 9                       10          San Jose    CA          47.07
# 59                      60         Sunnyvale    CA          38.62
# 4                        5           Oakland    CA          53.47
# ...
